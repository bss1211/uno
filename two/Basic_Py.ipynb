# %% [markdown]
# Chapter 1

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("this is NIsha's")
# Out:
# this is NIsha's

# %% [markdown]
#         Creating VAriable

# %%
name = 'bhupen'

# %%
type(name)
# Out:
# str

# %%
n = 22

# %%
type(n)
# Out:
# int

# %%
fname = 'sute'
lname = 'chai'

# %%
print(fname)
print(lname)
print(fname +" "+lname)
# Out:
# sute
# chai
# sute chai

# %%
learner_1 = 'kanchan'
learner_2 = 'ann'
learner_3 = 'kavya'
learner_4 = 'shruti'

print(learner_1 = 'kanchan')
print(learner_2 = 'ann')
print(learner_3 = 'kavya')
print(learner_4 = 'shruti')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c3216ff0567d> in <module>
#       4 learner_4 = 'shruti'
#       5
# ----> 6 print(learner_1 = 'kanchan')
#       7 print(learner_2 = 'ann')
#       8 print(learner_3 = 'kavya')
#
# TypeError: 'learner_1' is an invalid keyword argument for print()

# %%
user_input = input("Username: ")
user_input[0:2]
# Out:
# Username: lenovo
# 'le'

# %%
num_1 = (input('Enter number 1 : '))
num_2 = (input('Enter number 2 : '))

addition  = num_1 + num_2
print(addition)
# Out:
# Enter number 1 : 3
# Enter number 2 : 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e5b6226ea836> in <module>
#       3
#       4 addition  = num_1 + num_2
# ----> 5 print(addition)
#
# TypeError: 'float' object is not callable

# %%
max (10,2,2222,23)
# Out:
# 2222

# %%
min(45,44,2,4,4551,1)
# Out:
# 1

# %% [markdown]
#     Function

# %%
def get_num():
    print('oye oye')
    
get_num()
# Out:
# oye oye

# %%
def int_num():
    print('numnum')

# %%
int_num()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5ac1b3b984e8> in <module>
# ----> 1 int_num()
#
# NameError: name 'int_num' is not defined

# %%
import pandas as pd

# %%
income = pd.read_csv(r'C:\Users\Aragog\Documents\Jupyter\bhup\Prac panda ex\income.csv')
income
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
income.columns[0:2]
# Out:
# Index(['Index', 'State'], dtype='object')

# %%
income.columns
# Out:
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
income.dtypes
# Out:
# Index    object
# State    object
# Y2002     int64
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
income['State'].dtypes
# Out:
# dtype('O')

# %%
income.Y2008 = income.Y2008.astype(float)
income.dtypes
# Out:
# Index     object
# State     object
# Y2002      int64
# Y2003      int64
# Y2004      int64
# Y2005      int64
# Y2006      int64
# Y2007      int64
# Y2008    float64
# Y2009      int64
# Y2010      int64
# Y2011      int64
# Y2012      int64
# Y2013      int64
# Y2014      int64
# Y2015      int64
# dtype: object

# %%
income.shape
# Out:
# (51, 16)

# %%
income.shape[1]
# Out:
# 16

# %%
income.shape[0]
# Out:
# 51

# %%
income.head()
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#        Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229.0  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826.0  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886.0  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104.0  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315.0  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
income.tail()
# Out:
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 46     V       Virginia  1134317  1163996  1891068  1853855  1708715  1197698
# 47     W     Washington  1977749  1687136  1199490  1163092  1334864  1621989
# 48     W  West Virginia  1677347  1380662  1176100  1888948  1922085  1740826
# 49     W      Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W        Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#         Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 46  1803330.0  1590043  1516758  1171686  1262342  1647032  1706707  1850394
# 47  1545621.0  1555554  1179331  1150089  1775787  1273834  1387428  1377341
# 48  1238174.0  1539322  1539603  1872519  1462137  1683127  1204344  1198791
# 49  1980167.0  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602.0  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
income.head(3)
# Out:
#   Index    State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A  Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A   Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A  Arizona  1742027  1968140  1377583  1782199  1102568  1109382
#
#        Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229.0  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826.0  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886.0  1554330  1300521  1130709  1907284  1363279  1525866  1647724

# %%
income.tail(3)
# Out:
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 48     W  West Virginia  1677347  1380662  1176100  1888948  1922085  1740826
# 49     W      Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W        Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#         Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 48  1238174.0  1539322  1539603  1872519  1462137  1683127  1204344  1198791
# 49  1980167.0  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602.0  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
income[:5]
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#        Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229.0  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826.0  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886.0  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104.0  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315.0  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
income.iloc[0:5]
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#        Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229.0  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826.0  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886.0  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104.0  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315.0  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
income.Index.unique()
# Out:
# array(['A', 'C', 'D', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'O', 'P',
#        'R', 'S', 'T', 'U', 'V', 'W'], dtype=object)

# %%
income.Index.nunique()
# Out:
# 19

# %%
income.Index
# Out:
# 0     A
# 1     A
# 2     A
# 3     A
# 4     C
# 5     C
# 6     C
# 7     D
# 8     D
# 9     F
# 10    G
# 11    H
# 12    I
# 13    I
# 14    I
# 15    I
# 16    K
# 17    K
# 18    L
# 19    M
# 20    M
# 21    M
# 22    M
# 23    M
# 24    M
# 25    M
# 26    M
# 27    N
# 28    N
# 29    N
# 30    N
# 31    N
# 32    N
# 33    N
# 34    N
# 35    O
# 36    O
# 37    O
# 38    P
# 39    R
# 40    S
# 41    S
# 42    T
# 43    T
# 44    U
# 45    V
# 46    V
# 47    W
# 48    W
# 49    W
# 50    W
# Name: Index, dtype: object

# %%
pd.crosstab(income.Index,income.State)
# Out:
# State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Index
# A            1       1        1         1           0         0            0
# C            0       0        0         0           1         1            1
# D            0       0        0         0           0         0            0
# F            0       0        0         0           0         0            0
# G            0       0        0         0           0         0            0
# H            0       0        0         0           0         0            0
# I            0       0        0         0           0         0            0
# K            0       0        0         0           0         0            0
# L            0       0        0         0           0         0            0
# M            0       0        0         0           0         0            0
# N            0       0        0         0           0         0            0
# ...

# %%
pd.Series([1,2,3,1,2],dtype='category')
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
import pandas as pd

# %%
sales_2017 = pd.read_csv(r'C:\Users\Aragog\Documents\Jupyter\John\Sales Transactions-2017.csv')
sales_2018 = pd.read_csv(r'C:\Users\Aragog\Documents\Jupyter\John\Sales Transactions-2018.csv')
sales_2019 = pd.read_csv(r'C:\Users\Aragog\Documents\Jupyter\John\Sales Transactions-2019.csv')

sales_2017

# %%
sales_2017.shape
# Out:
# (47290, 9)

# %%
sales_2018.shape
# Out:
# (44740, 9)

# %%
sales_2019.shape
# Out:
# (19176, 9)

# %%
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_2017.info
# Out:
# <bound method DataFrame.info of              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2017.describe
# Out:
# <bound method NDFrame.describe of              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2017.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_2018.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_2019.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_2017.isnull().sum()
# Out:
# Date               5388
# Voucher            5375
# Party                15
# Product            5388
# Qty                5375
# Rate               5376
# Gross              5376
# Disc              44432
# Voucher Amount    35942
# dtype: int64

# %%
sales_2018.isnull().sum()
# Out:
# Date               5413
# Voucher            5400
# Party                15
# Product            5413
# Qty                5400
# Rate               5400
# Gross              5400
# Disc              42778
# Voucher Amount    33916
# dtype: int64

# %%
sales_2019.isnull().sum()
# Out:
# Date               1790
# Voucher            1782
# Party                10
# Product            1790
# Qty                1782
# Rate               1782
# Gross              1782
# Disc              18399
# Voucher Amount    13788
# dtype: int64

# %%
insurance = pd.read_csv(r'C:\Users\Aragog\Documents\Jupyter\John\insurance.csv')
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
insurance.sex.nunique()
# Out:
# 2

# %%
insurance.bmi.nunique()
# Out:
# 548

# %%
insurance.groupby(['sex','smoker','region']).mean()
# Out:
#                                age        bmi  children       charges
# sex    smoker region
# female no     northeast  39.840909  29.777462  0.954545   9640.426984
#               northwest  39.755556  29.488704  1.177778   8786.998679
#               southeast  39.071942  32.780000  1.079137   8440.205552
#               southwest  40.099291  30.050355  1.134752   8234.091260
#        yes    northeast  38.724138  27.261724  1.241379  28032.046398
#               northwest  38.827586  28.296897  0.827586  29670.824946
#               southeast  39.250000  32.251389  0.944444  33034.820716
#               southwest  37.047619  30.128571  1.047619  31687.988430
# male   no     northeast  39.216000  28.861760  1.144000   8664.042222
#               northwest  38.568182  28.930379  1.060606   8320.689321
#               southeast  38.261194  34.129552  1.052239   7609.003587
#               southwest  40.277778  31.019841  1.119048   7778.905534
# ...

# %%
insurance.groupby('region'),['smoker','region'].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-791fc8c8ce57> in <module>
# ----> 1 insurance.groupby('region'),['smoker','region'].mean()
#
# AttributeError: 'list' object has no attribute 'mean'
